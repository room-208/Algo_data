# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv('data_1.csv')
df_4 = pd.read_csv('data_4.csv')
df_6 = pd.read_csv('data_6.csv')
df_7 = pd.read_csv('data_7.csv')
df_8 = pd.read_csv('data_8.csv')
df_9 = pd.read_csv('data_9.csv')

# %%
plt.figure()
plt.plot(np.log(df_1['N']),np.log(df_1['time[ms]']))
plt.plot(np.log(df_4['N']),np.log(df_4['time[ms]']))
plt.plot(np.log(df_6['N']),np.log(df_6['time[ms]']))
plt.plot(np.log(df_7['N']),np.log(df_7['time[ms]']))
plt.plot(np.log(df_9['N']),np.log(df_9['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter3D(np.log(df_8['N']),np.log(df_8['M']),np.log(df_8['time[ms]']))
#ax.set_title("Scatter Plot")
#plt.show()

# %%
ts_1 = pd.read_csv('test_1.csv')
ts_3 = pd.read_csv('test_3.csv')
ts_4 = pd.read_csv('test_4.csv')
ts_5 = pd.read_csv('test_5.csv')
ts_6 = pd.read_csv('test_6.csv')
ts_7 = pd.read_csv('test_7.csv')
ts_8 = pd.read_csv('test_8.csv')
ts_9 = pd.read_csv('test_9.csv')

# %%
plt.figure()
plt.plot(np.log(ts_1['N']),np.log(ts_1['time[ms]']))
plt.plot(np.log(ts_3['N']),np.log(ts_3['time[ms]']))
plt.plot(np.log(ts_4['N']),np.log(ts_4['time[ms]']))
plt.plot(np.log(ts_9['N']),np.log(ts_9['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter3D(np.log(ts_7['N']),np.log(ts_7['M']),np.log(ts_7['time[ms]']))
#ax.set_title("Scatter Plot")
#plt.show()

# %%
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter3D(np.log(ts_8['N']),np.log(ts_8['M']),np.log(ts_8['time[ms]']))
#ax.view_init(elev=10, azim=180)
#ax.set_title("Scatter Plot")
#plt.show()

# %%
plt.figure()
plt.plot(np.log(ts_5['N']),np.log(ts_5['time[ms]']))
plt.plot(np.log(ts_5['W']),np.log(ts_5['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(np.log(ts_6['N']),np.log(ts_6['time[ms]']))
plt.plot(np.log(ts_6['W']),np.log(ts_6['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
