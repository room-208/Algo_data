# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_1 = pd.read_csv('data_1.csv')
df_2 = pd.read_csv('data_2.csv')
df_4 = pd.read_csv('data_4.csv')
df_5 = pd.read_csv('data_5.csv')

# %%
plt.figure()
plt.plot(np.log(df_1['N']),df_1['count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(np.log(df_2['N']),df_2['count'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(df_4['N'],df_4['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(df_5['N'],df_5['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ts_1 = pd.read_csv('test_1.csv')
ts_2 = pd.read_csv('test_2.csv')
ts_3 = pd.read_csv('test_3.csv')
ts_4 = pd.read_csv('test_4.csv')
ts_5 = pd.read_csv('test_5.csv')

# %%
plt.figure()
plt.plot(ts_1['N'],ts_1['time[ms]'])
plt.plot(ts_3['N'],ts_3['time[ms]'])
plt.plot(ts_5['N'],ts_5['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(np.log(ts_1['N']),np.log(ts_1['time[ms]']))
plt.plot(np.log(ts_3['N']),np.log(ts_3['time[ms]']))
plt.plot(np.log(ts_5['N']),np.log(ts_5['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(ts_2['N'],ts_2['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(ts_4['N'],ts_4['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
