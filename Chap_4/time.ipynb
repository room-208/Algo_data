# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_6 = pd.read_csv('data_6.csv')
df_7 = pd.read_csv('data_7.csv')
df_9 = pd.read_csv('data_9.csv')
ts_1 = pd.read_csv('test_1.csv')
ts_2 = pd.read_csv('test_2.csv')

# %%
plt.figure()
plt.plot(df_6['N'],np.log(df_6['time[ms]']))
plt.plot(df_9['N'],np.log(df_9['time[ms]']))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(ts_1['K'],ts_1['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure()
plt.plot(df_7['N'],df_7['time[ms]'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
